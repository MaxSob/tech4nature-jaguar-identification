# %%
import pandas as pd
import numpy as np

# %%
def calculate_metrics(tp, tn, fp, fn):
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_score = (2 * precision * recall) / (precision + recall)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    return precision, recall, f1_score, accuracy

# %%
# Load data from CSV into dataframes
model_1 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_1.csv')
model_1_1 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_1_1.csv')

model_2 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_2.csv')
model_2_1 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_2_1.csv')

model_3 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_3.csv')
model_3_1 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_3_1.csv')

model_3v2 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_3v2.csv')
model_3v2_1 = pd.read_csv('/content/drive/MyDrive/final_eval/preds_df/df_3v2_1.csv')

# %%
def calculate_metrics_at_thresholds(df, thresholds):
    # Create empty lists to store the metrics for each iteration
    precision_list = []
    recall_list = []
    f1_score_list = []
    accuracy_list = []

    # Iterate over the thresholds and calculate the metrics for each iteration
    for threshold in thresholds:

        tp = len(df.query("correct_label == 'jaguar' and predicted_label == 'jaguar' and prediction_probability >= @threshold"))
        tn = len(df.query("correct_label == 'no-jaguar' and predicted_label == 'no-jaguar' and prediction_probability < @threshold"))
        fp = len(df.query("correct_label == 'no-jaguar' and predicted_label == 'jaguar' and prediction_probability >= @threshold"))
        fn = len(df.query("correct_label == 'jaguar' and predicted_label == 'no-jaguar' and prediction_probability >= @threshold"))

        precision, recall, f1_score, accuracy = calculate_metrics(tp, tn, fp, fn)

        # Append the metrics to the lists
        precision_list.append(round(precision, 4))
        recall_list.append(round(recall, 4))
        f1_score_list.append(round(f1_score, 4))
        accuracy_list.append(round(accuracy, 4))

    # Create a dictionary with the metric values for each threshold
    metrics_dict = {'Threshold': thresholds, 'Accuracy': accuracy_list, 'Precision': precision_list, 'Recall': recall_list, 'F1 Score': f1_score_list}

    # Convert the dictionary to a pandas dataframe
    metrics_df = pd.DataFrame.from_dict(metrics_dict)

    return metrics_df

# %% [markdown]
# ## MODEL 1 (threshold >= 50)

# %% [markdown]
# #### MODEL 1 (128, 128, 3)

# %%
df = model_1

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]

# %%
metrics_df_1_t = calculate_metrics_at_thresholds(df_filtered, [70, 80, 90])
metrics_df = metrics_df_1_t

# %%
metrics_df_1_t
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.2309     0.2309     1.0    0.3752
# 1         80    0.2246     0.2246     1.0    0.3668
# 2         90    0.1944     0.1944     1.0    0.3256

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 1 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3c5035c2-505f-49bc-923e-2668e04bd94f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c5035c2-505f-49bc-923e-2668e04bd94f")) {                    Plotly.newPlot(                        "3c5035c2-505f-49bc-923e-2668e04bd94f",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.2309,0.2246,0.1944],"textposition":"top center","x":[70,80,90],"y":[0.2309,0.2246,0.1944],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.2309,0.2246,0.1944],"textposition":"top center","x":[70,80,90],"y":[0.2309,0.2246,0.1944],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[70,80,90],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.3752,0.3668,0.3256],"textposition":"top center","x":[70,80,90],"y":[0.3752,0.3668,0.3256],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"co ...

# %% [markdown]
# #### MODEL 1 (224, 224, 3)

# %%
df = model_1_1

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]

# %%
df_filtered
# Out:
#                                             image_file correct_label  \
# 6    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 11   test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 13   test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 22   test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 33   test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# ..                                                 ...           ...
# 795  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 796  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 797  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 798  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 799  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
#
#     predicted_label  prediction_probability
# 6            jaguar                   99.94
# 11           jaguar                   99.83
# 13           jaguar                   98.16
# 22           jaguar                   57.18
# 33           jaguar                   99.95
# ..              ...                     ...
# 795          jaguar                   98.04
# 796          jaguar                   96.39
# 797          jaguar                   97.61
# 798          jaguar                   95.89
# 799          jaguar                   93.97
#
# [428 rows x 4 columns]

# %%
metrics_df_1_1_t = calculate_metrics_at_thresholds(df_filtered, [70, 80, 90])
metrics_df = metrics_df_1_1_t
metrics_df_1_1_t
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.1571     0.1571     1.0    0.2715
# 1         80    0.1335     0.1335     1.0    0.2356
# 2         90    0.1258     0.1258     1.0    0.2235

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 1 (224x224)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="04017d9b-9c42-440b-ba68-6e90657b012d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04017d9b-9c42-440b-ba68-6e90657b012d")) {                    Plotly.newPlot(                        "04017d9b-9c42-440b-ba68-6e90657b012d",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.1571,0.1335,0.1258],"textposition":"top center","x":[70,80,90],"y":[0.1571,0.1335,0.1258],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.1571,0.1335,0.1258],"textposition":"top center","x":[70,80,90],"y":[0.1571,0.1335,0.1258],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[70,80,90],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.2715,0.2356,0.2235],"textposition":"top center","x":[70,80,90],"y":[0.2715,0.2356,0.2235],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"co ...

# %% [markdown]
# ## MODEL 1 Total

# %% [markdown]
# #### MODEL 1 (128, 128, 3)

# %%
# Filter rows with prediction probability greater than 0.5
df_filtered = model_1
df_filtered
# Out:
#                                             image_file correct_label  \
# 0    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 1    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 2    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 3    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 4    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# ..                                                 ...           ...
# 795  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 796  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 797  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 798  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 799  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
#
#     predicted_label  prediction_probability
# 0            jaguar                    1.10
# 1            jaguar                    0.00
# 2            jaguar                   83.49
# 3            jaguar                    2.20
# 4            jaguar                    0.00
# ..              ...                     ...
# 795          jaguar                   99.82
# 796          jaguar                   99.84
# 797          jaguar                   99.72
# 798          jaguar                   99.64
# 799          jaguar                   99.99
#
# [800 rows x 4 columns]

# %%
metrics_df_1_to = calculate_metrics_at_thresholds(df_filtered, [0.7, 0.8, 0.9])
metrics_df = metrics_df_1_to

# %%
metrics_df_1_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.7    0.3565     0.3565     1.0    0.5256
# 1        0.8    0.3544     0.3544     1.0    0.5233
# 2        0.9    0.3523     0.3523     1.0    0.5210

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 1 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c9f3caee-5247-4680-941c-03c9dafdd7aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9f3caee-5247-4680-941c-03c9dafdd7aa")) {                    Plotly.newPlot(                        "c9f3caee-5247-4680-941c-03c9dafdd7aa",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.3565,0.3544,0.3523],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.3565,0.3544,0.3523],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.3565,0.3544,0.3523],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.3565,0.3544,0.3523],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[0.7,0.8,0.9],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.5256,0.5233,0.521],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.5256,0.5233,0.521],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"err ...

# %% [markdown]
# #### MODEL 1 (224, 224, 3)

# %%
# Filter rows with prediction probability greater than 0.5
df_filtered = model_1_1
df_filtered
# Out:
#                                             image_file correct_label  \
# 0    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 1    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 2    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 3    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# 4    test01/test_sample/jaguar_sample/test_jaguar_1...        jaguar
# ..                                                 ...           ...
# 795  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 796  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 797  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 798  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 799  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
#
#     predicted_label  prediction_probability
# 0            jaguar                    2.26
# 1            jaguar                    0.04
# 2            jaguar                    8.79
# 3            jaguar                    0.09
# 4            jaguar                    0.06
# ..              ...                     ...
# 795          jaguar                   98.04
# 796          jaguar                   96.39
# 797          jaguar                   97.61
# 798          jaguar                   95.89
# 799          jaguar                   93.97
#
# [800 rows x 4 columns]

# %%
metrics_df_1_1_to = calculate_metrics_at_thresholds(df_filtered, [0.7, 0.8, 0.9])
metrics_df = metrics_df_1_1_to

# %%
metrics_df_1_1_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.7    0.3930     0.3930     1.0    0.5642
# 1        0.8    0.3883     0.3883     1.0    0.5594
# 2        0.9    0.3835     0.3835     1.0    0.5544

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 1 (224x224)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b5b214a6-b676-4983-a3d9-74f7f5fe7183" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5b214a6-b676-4983-a3d9-74f7f5fe7183")) {                    Plotly.newPlot(                        "b5b214a6-b676-4983-a3d9-74f7f5fe7183",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.393,0.3883,0.3835],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.393,0.3883,0.3835],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.393,0.3883,0.3835],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.393,0.3883,0.3835],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[0.7,0.8,0.9],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.5642,0.5594,0.5544],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.5642,0.5594,0.5544],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error ...

# %% [markdown]
# ## MODEL 2 (threshold >= 50)

# %% [markdown]
# #### MODEL 2 (128, 128, 3)

# %%
df = model_2

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]
df_filtered['prediction_probability'].unique()
# Out:
# array([66.81, 66.8 , 66.82, 66.77, 67.01, 66.79, 66.89, 66.73, 66.76,
#        66.83, 66.66, 66.75, 66.84, 66.71, 66.78, 66.85, 66.63, 66.74,
#        66.72, 66.95, 66.88, 66.69, 66.97, 66.87, 67.  , 66.99, 66.64,
#        67.27, 67.29, 66.6 , 67.1 , 66.91, 66.86, 66.98, 66.9 , 66.94,
#        66.62, 67.07, 66.7 , 66.61, 66.92, 66.67, 67.39, 67.68, 66.68,
#        66.65, 67.21, 67.2 , 67.04, 67.42, 67.03, 66.93, 67.28, 67.09,
#        67.08, 67.35, 67.12, 66.96, 67.05, 67.19, 66.59, 66.57, 67.15,
#        66.56, 66.58])

# %%
metrics_df_2_t = calculate_metrics_at_thresholds(df_filtered, [50, 60])
metrics_df = metrics_df_2_t
metrics_df_2_t
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         50       0.5        0.5     1.0    0.6667
# 1         60       0.5        0.5     1.0    0.6667

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 2 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="de1bc2cf-c163-4147-9d3a-35e05974d8f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de1bc2cf-c163-4147-9d3a-35e05974d8f5")) {                    Plotly.newPlot(                        "de1bc2cf-c163-4147-9d3a-35e05974d8f5",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.5,0.5],"textposition":"top center","x":[50,60],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.5,0.5],"textposition":"top center","x":[50,60],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0],"textposition":"top center","x":[50,60],"y":[1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.6667,0.6667],"textposition":"top center","x":[50,60],"y":[0.6667,0.6667],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","wid ...

# %% [markdown]
# #### MODEL 2 (224, 224, 3)

# %%
df = model_2_1

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]

# %%
metrics_df_2_1_t = calculate_metrics_at_thresholds(df_filtered, [50, 60])
metrics_df = metrics_df_2_1_t

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Threshold Metrics')

# Set the legend
fig.update_layout(legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01))

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6af825f7-b2ad-4bc3-a28a-734d61ebfb57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6af825f7-b2ad-4bc3-a28a-734d61ebfb57")) {                    Plotly.newPlot(                        "6af825f7-b2ad-4bc3-a28a-734d61ebfb57",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.5,0.5],"textposition":"top center","x":[50,60],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.5,0.5],"textposition":"top center","x":[50,60],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0],"textposition":"top center","x":[50,60],"y":[1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.6667,0.6667],"textposition":"top center","x":[50,60],"y":[0.6667,0.6667],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","wid ...

# %% [markdown]
# ## MODEL 2 Total

# %% [markdown]
# #### MODEL 2 (128, 128, 3)

# %%
# Filter rows with prediction probability greater than 0.5
df_filtered = model_2

# %%
metrics_df_2_to = calculate_metrics_at_thresholds(df_filtered, [0.5, 0.6])
metrics_df = metrics_df_2_to
metrics_df_2_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.5       0.5        0.5     1.0    0.6667
# 1        0.6       0.5        0.5     1.0    0.6667

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 2 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e6c48f51-cef6-4b9f-8433-7d4cb305a86f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6c48f51-cef6-4b9f-8433-7d4cb305a86f")) {                    Plotly.newPlot(                        "e6c48f51-cef6-4b9f-8433-7d4cb305a86f",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.5,0.5],"textposition":"top center","x":[0.5,0.6],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.5,0.5],"textposition":"top center","x":[0.5,0.6],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0],"textposition":"top center","x":[0.5,0.6],"y":[1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.6667,0.6667],"textposition":"top center","x":[0.5,0.6],"y":[0.6667,0.6667],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5EC ...

# %% [markdown]
# #### MODEL 2 (224, 224, 3)

# %%
# Filter rows with prediction probability greater than 0.5
df_filtered = model_2_1

# %%
metrics_df_2_1 = calculate_metrics_at_thresholds(df_filtered, [0.5, 0.6])
metrics_df = metrics_df_2_1
metrics_df_2_1
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.5       0.5        0.5     1.0    0.6667
# 1        0.6       0.5        0.5     1.0    0.6667

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 2 (224x224)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4c83c440-df2c-4a75-abac-ebe64d537c91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c83c440-df2c-4a75-abac-ebe64d537c91")) {                    Plotly.newPlot(                        "4c83c440-df2c-4a75-abac-ebe64d537c91",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.5,0.5],"textposition":"top center","x":[0.5,0.6],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.5,0.5],"textposition":"top center","x":[0.5,0.6],"y":[0.5,0.5],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0],"textposition":"top center","x":[0.5,0.6],"y":[1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.6667,0.6667],"textposition":"top center","x":[0.5,0.6],"y":[0.6667,0.6667],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5EC ...

# %% [markdown]
# ## MODEL 3 (threshold >= 50)

# %% [markdown]
# #### MODEL 3 (128, 128, 3)

# %%
df = model_3

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]

# %%
metrics_df_3_t = calculate_metrics_at_thresholds(df_filtered, [70,80, 90])
metrics_df = metrics_df_3_t
metrics_df_3_t
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.8799     0.8799     1.0    0.9361
# 1         80    0.8855     0.8855     1.0    0.9393
# 2         90    0.8988     0.8988     1.0    0.9467

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 1 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fba2ddc2-0d15-4b59-913a-379f1d72aa53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fba2ddc2-0d15-4b59-913a-379f1d72aa53")) {                    Plotly.newPlot(                        "fba2ddc2-0d15-4b59-913a-379f1d72aa53",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.8799,0.8855,0.8988],"textposition":"top center","x":[70,80,90],"y":[0.8799,0.8855,0.8988],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.8799,0.8855,0.8988],"textposition":"top center","x":[70,80,90],"y":[0.8799,0.8855,0.8988],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[70,80,90],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.9361,0.9393,0.9467],"textposition":"top center","x":[70,80,90],"y":[0.9361,0.9393,0.9467],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"co ...

# %% [markdown]
# #### MODEL 3 (224, 224, 3)

# %%
df = model_3_1

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]

# %%
metrics_df_3_1_t = calculate_metrics_at_thresholds(df_filtered, [70,80, 90])
metrics_df = metrics_df_3_1_t
metrics_df_3_1_t
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.9710     0.9710     1.0    0.9853
# 1         80    0.9731     0.9731     1.0    0.9863
# 2         90    0.9779     0.9779     1.0    0.9888

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 3 (224x224)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="87b7afd8-a5e7-48c2-b976-9d7670b6d69b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87b7afd8-a5e7-48c2-b976-9d7670b6d69b")) {                    Plotly.newPlot(                        "87b7afd8-a5e7-48c2-b976-9d7670b6d69b",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.971,0.9731,0.9779],"textposition":"top center","x":[70,80,90],"y":[0.971,0.9731,0.9779],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.971,0.9731,0.9779],"textposition":"top center","x":[70,80,90],"y":[0.971,0.9731,0.9779],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[70,80,90],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.9853,0.9863,0.9888],"textposition":"top center","x":[70,80,90],"y":[0.9853,0.9863,0.9888],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color" ...

# %% [markdown]
# ## MODEL 3 Total

# %% [markdown]
# #### MODEL 3 (128, 128, 3)

# %%
# Filter rows with prediction probability greater than 0.5
df_filtered = model_3
df_filtered = df_filtered.query("prediction_probability < 10 & correct_label == 'no-jaguar'" )
df_filtered
# Out:
#                                             image_file correct_label  \
# 401  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 402  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 403  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 405  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 406  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# ..                                                 ...           ...
# 795  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 796  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 797  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 798  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
# 799  test01/test_sample/no-jaguar_sample/test_no-ja...     no-jaguar
#
#     predicted_label  prediction_probability
# 401          jaguar                    0.01
# 402          jaguar                    0.13
# 403          jaguar                    0.00
# 405          jaguar                    0.50
# 406          jaguar                    0.00
# ..              ...                     ...
# 795          jaguar                    0.00
# 796          jaguar                    0.02
# 797          jaguar                    0.00
# 798          jaguar                    0.10
# 799          jaguar                    0.00
#
# [321 rows x 4 columns]

# %%
metrics_df_3_to = calculate_metrics_at_thresholds(df_filtered, [0.7,0.8, 0.9])
metrics_df = metrics_df_3_to
metrics_df_3_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.7    0.7591     0.7591     1.0    0.8630
# 1        0.8    0.7660     0.7660     1.0    0.8675
# 2        0.9    0.7689     0.7689     1.0    0.8694

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 3 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="02d4fa43-941f-4026-9f89-808ce81f9fa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02d4fa43-941f-4026-9f89-808ce81f9fa0")) {                    Plotly.newPlot(                        "02d4fa43-941f-4026-9f89-808ce81f9fa0",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.7591,0.766,0.7689],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.7591,0.766,0.7689],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.7591,0.766,0.7689],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.7591,0.766,0.7689],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[0.7,0.8,0.9],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.863,0.8675,0.8694],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.863,0.8675,0.8694],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x ...

# %% [markdown]
# #### MODEL 3 (224, 224, 3)

# %%
# Filter rows with prediction probability greater than 0.5
df_filtered = model_3_1

# %%
metrics_df_3_1_to = calculate_metrics_at_thresholds(df_filtered, [0.7,0.8, 0.9])
metrics_df = metrics_df_3_1_to
metrics_df_3_1_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.7    0.8453     0.8453     1.0    0.9162
# 1        0.8    0.8546     0.8546     1.0    0.9216
# 2        0.9    0.8559     0.8559     1.0    0.9223

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 3 (224x224)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0c4dc347-4b02-40dd-b3b5-db3bebbb88e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c4dc347-4b02-40dd-b3b5-db3bebbb88e1")) {                    Plotly.newPlot(                        "0c4dc347-4b02-40dd-b3b5-db3bebbb88e1",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.8453,0.8546,0.8559],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.8453,0.8546,0.8559],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.8453,0.8546,0.8559],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.8453,0.8546,0.8559],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[1.0,1.0,1.0],"textposition":"top center","x":[0.7,0.8,0.9],"y":[1.0,1.0,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.9162,0.9216,0.9223],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.9162,0.9216,0.9223],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"e ...

# %% [markdown]
# ## MODEL 3v2 (threshold >= 50)

# %% [markdown]
# #### MODEL 3v2 (128, 128, 3)

# %%
df = model_3v2

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]

# %%
metrics_df_3v2_t = calculate_metrics_at_thresholds(df_filtered, [70,80, 90])
metrics_df = metrics_df_3v2_t
metrics_df_3v2_t
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.8720     0.9468  0.9152    0.9307
# 1         80    0.8765     0.9492  0.9173    0.9330
# 2         90    0.8814     0.9539  0.9167    0.9349

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 4 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d95c8291-1021-46e3-a249-e36fbeccc6a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d95c8291-1021-46e3-a249-e36fbeccc6a4")) {                    Plotly.newPlot(                        "d95c8291-1021-46e3-a249-e36fbeccc6a4",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.872,0.8765,0.8814],"textposition":"top center","x":[70,80,90],"y":[0.872,0.8765,0.8814],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.9468,0.9492,0.9539],"textposition":"top center","x":[70,80,90],"y":[0.9468,0.9492,0.9539],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[0.9152,0.9173,0.9167],"textposition":"top center","x":[70,80,90],"y":[0.9152,0.9173,0.9167],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.9307,0.933,0.9349],"textposition":"top center","x":[70,80,90],"y":[0.9307,0.933,0.9349],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{ ...

# %% [markdown]
# #### MODEL 3v2 (224, 224, 3)

# %%
df = model_3v2_1

# Filter rows with prediction probability greater than 0.5
df_filtered = df[df['prediction_probability'] >= 50]

# %%
metrics_df_3v2_1_t = calculate_metrics_at_thresholds(df_filtered, [70,80, 90])
metrics_df = metrics_df_3v2_1_t
metrics_df_3v2_1_t
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.8860     0.9248  0.9549    0.9396
# 1         80    0.8871     0.9248  0.9549    0.9396
# 2         90    0.8871     0.9246  0.9548    0.9394

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Threshold Metrics')

# Set the legend
fig.update_layout(legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01))

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="23774101-6743-40fb-895d-fd564f2d8d30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23774101-6743-40fb-895d-fd564f2d8d30")) {                    Plotly.newPlot(                        "23774101-6743-40fb-895d-fd564f2d8d30",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.886,0.8871,0.8871],"textposition":"top center","x":[70,80,90],"y":[0.886,0.8871,0.8871],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.9248,0.9248,0.9246],"textposition":"top center","x":[70,80,90],"y":[0.9248,0.9248,0.9246],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[0.9549,0.9549,0.9548],"textposition":"top center","x":[70,80,90],"y":[0.9549,0.9549,0.9548],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.9396,0.9396,0.9394],"textposition":"top center","x":[70,80,90],"y":[0.9396,0.9396,0.9394],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar": ...

# %% [markdown]
# ## MODEL 3v2 Total

# %% [markdown]
# #### MODEL 3v2 (128, 128, 3)

# %%
df_filtered = model_3v2

# %%
metrics_df_3v2_to = calculate_metrics_at_thresholds(df_filtered, [70,80, 90])
metrics_df = metrics_df_3v2_to
metrics_df_3v2_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.8720     0.9468  0.9152    0.9307
# 1         80    0.8765     0.9492  0.9173    0.9330
# 2         90    0.8814     0.9539  0.9167    0.9349

# %%
metrics_df_3v2_to.loc[:, 'Threshold'] = [0.7, 0.8, 0.9]
metrics_df_3v2_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.7    0.8720     0.9468  0.9152    0.9307
# 1        0.8    0.8765     0.9492  0.9173    0.9330
# 2        0.9    0.8814     0.9539  0.9167    0.9349

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 4 (128x128)')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7c5fb8d3-c9e8-475b-8b79-1301ffb7f6c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c5fb8d3-c9e8-475b-8b79-1301ffb7f6c8")) {                    Plotly.newPlot(                        "7c5fb8d3-c9e8-475b-8b79-1301ffb7f6c8",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.872,0.8765,0.8814],"textposition":"top center","x":[70,80,90],"y":[0.872,0.8765,0.8814],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.9468,0.9492,0.9539],"textposition":"top center","x":[70,80,90],"y":[0.9468,0.9492,0.9539],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[0.9152,0.9173,0.9167],"textposition":"top center","x":[70,80,90],"y":[0.9152,0.9173,0.9167],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.9307,0.933,0.9349],"textposition":"top center","x":[70,80,90],"y":[0.9307,0.933,0.9349],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{ ...

# %% [markdown]
# #### MODEL 3v2 (224, 224, 3)

# %%
df_filtered = model_3v2_1

# %%
metrics_df_3v2_1_to = calculate_metrics_at_thresholds(df_filtered, [70,80, 90])
metrics_df = metrics_df_3v2_1_to

# %%
metrics_df_3v2_1_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0         70    0.8860     0.9248  0.9549    0.9396
# 1         80    0.8871     0.9248  0.9549    0.9396
# 2         90    0.8871     0.9246  0.9548    0.9394

# %%
metrics_df_3v2_1_to.loc[:, 'Threshold'] = [0.7, 0.8, 0.9]
metrics_df_3v2_1_to
# Out:
#    Threshold  Accuracy  Precision  Recall  F1 Score
# 0        0.7    0.8860     0.9248  0.9549    0.9396
# 1        0.8    0.8871     0.9248  0.9549    0.9396
# 2        0.9    0.8871     0.9246  0.9548    0.9394

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the traces for each metric with text labels
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Accuracy'], name='Accuracy', text=metrics_df['Accuracy'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Precision'], name='Precision', text=metrics_df['Precision'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['Recall'], name='Recall', text=metrics_df['Recall'], mode='lines+markers+text', textposition="top center"))
fig.add_trace(go.Scatter(x=metrics_df['Threshold'], y=metrics_df['F1 Score'], name='F1 Score', text=metrics_df['F1 Score'], mode='lines+markers+text', textposition="top center"))

# Set the axis labels and title
fig.update_layout(xaxis_title='Threshold', yaxis_title='Metric Value', title='Model 4 (224x224)')

# Set the legend


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b482114d-f11b-4f9b-84ec-89955c3c0bb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b482114d-f11b-4f9b-84ec-89955c3c0bb3")) {                    Plotly.newPlot(                        "b482114d-f11b-4f9b-84ec-89955c3c0bb3",                        [{"mode":"lines+markers+text","name":"Accuracy","text":[0.886,0.8871,0.8871],"textposition":"top center","x":[70,80,90],"y":[0.886,0.8871,0.8871],"type":"scatter"},{"mode":"lines+markers+text","name":"Precision","text":[0.9248,0.9248,0.9246],"textposition":"top center","x":[70,80,90],"y":[0.9248,0.9248,0.9246],"type":"scatter"},{"mode":"lines+markers+text","name":"Recall","text":[0.9549,0.9549,0.9548],"textposition":"top center","x":[70,80,90],"y":[0.9549,0.9549,0.9548],"type":"scatter"},{"mode":"lines+markers+text","name":"F1 Score","text":[0.9396,0.9396,0.9394],"textposition":"top center","x":[70,80,90],"y":[0.9396,0.9396,0.9394],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar": ...

# %% [markdown]
# ## Last results

# %%
def create_f1_score_comparison_plot(dfs, labels):
    # Create the figure
    fig = go.Figure()

    # Add the traces for each dataframe
    for i in range(len(dfs)):
        fig.add_trace(go.Scatter(x=dfs[i]['Threshold'], y=dfs[i]['F1 Score'], name=labels[i], mode='lines+markers+text', textposition="top center", text=dfs[i]['F1 Score']))

    # Set the axis labels and title
    fig.update_layout(xaxis_title='Threshold', yaxis_title='F1 Score', title='Total F1 Score Comparison')
    

    # Show the plot
    fig.show()

# %%
dfs = [metrics_df_1_t, metrics_df_1_1_t, metrics_df_3_t, metrics_df_3_1_t, metrics_df_3v2_t, metrics_df_3v2_1_t]

# %%
create_f1_score_comparison_plot(dfs, ['Modelo 1 (128x128)', 'Modelo 1(224x224)', 'Modelo 3(128x128)','Modelo 3(224x224)', 'Modelo 4(128x128)', 'Modelo 4(224x224)'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="96d4d147-4756-47ec-94e1-75dc72932c4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96d4d147-4756-47ec-94e1-75dc72932c4d")) {                    Plotly.newPlot(                        "96d4d147-4756-47ec-94e1-75dc72932c4d",                        [{"mode":"lines+markers+text","name":"Modelo 1 (128x128)","text":[0.3752,0.3668,0.3256],"textposition":"top center","x":[70,80,90],"y":[0.3752,0.3668,0.3256],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 1(224x224)","text":[0.2715,0.2356,0.2235],"textposition":"top center","x":[70,80,90],"y":[0.2715,0.2356,0.2235],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 3(128x128)","text":[0.9361,0.9393,0.9467],"textposition":"top center","x":[70,80,90],"y":[0.9361,0.9393,0.9467],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 3(224x224)","text":[0.9853,0.9863,0.9888],"textposition":"top center","x":[70,80,90],"y":[0.9853,0.9863,0.9888],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 4(128x128)","text":[0.9307,0.933,0.9349],"textposition":"top center","x":[70,80,90],"y":[0.9307,0.933,0.9349],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 4(224x224)","text":[0.9396,0.9396,0.9394],"textposition":"top center","x":[70,80,90],"y":[0.9396,0.9396,0.9394],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %%
dfs = [metrics_df_1_to, metrics_df_1_1_to, metrics_df_3_to, metrics_df_3_1_to, metrics_df_3v2_to, metrics_df_3v2_1_to]

# %%
create_f1_score_comparison_plot(dfs, ['Modelo 1 (128x128)', 'Modelo 1(224x224)', 'Modelo 3(128x128)','Modelo 3(224x224)', 'Modelo 4(128x128)', 'Modelo 4(224x224)'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a75b97e1-e407-4f00-9b4d-cd7804cec3e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a75b97e1-e407-4f00-9b4d-cd7804cec3e1")) {                    Plotly.newPlot(                        "a75b97e1-e407-4f00-9b4d-cd7804cec3e1",                        [{"mode":"lines+markers+text","name":"Modelo 1 (128x128)","text":[0.5256,0.5233,0.521],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.5256,0.5233,0.521],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 1(224x224)","text":[0.5642,0.5594,0.5544],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.5642,0.5594,0.5544],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 3(128x128)","text":[0.863,0.8675,0.8694],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.863,0.8675,0.8694],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 3(224x224)","text":[0.9162,0.9216,0.9223],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.9162,0.9216,0.9223],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 4(128x128)","text":[0.9307,0.933,0.9349],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.9307,0.933,0.9349],"type":"scatter"},{"mode":"lines+markers+text","name":"Modelo 4(224x224)","text":[0.9396,0.9396,0.9394],"textposition":"top center","x":[0.7,0.8,0.9],"y":[0.9396,0.9396,0.9394],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[ ...
