# %%
# Just one 
import moxing as mox
mox.file.copy_parallel("obs://jaguars-dataset/dataset1", "test01/")

# %%
# !pip install tensorflow==2.9.1

# %%
# !pip install -U scikit-learn

# %%
import tensorflow as tf
tf.__version__

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers

from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, f1_score, precision_score, confusion_matrix

# %%
import imutils
import os
import cv2
import datetime
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer

# %%
img_size = (224,224)
batch = 16

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../test01/train_sample/',
    validation_split = 0.25,
    subset = 'training',
    seed=123,
    image_size= img_size,
    batch_size = batch,
    label_mode = 'binary'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../test01/val/",
    validation_split = 0.25,
    subset = 'validation',
    seed=123,
    image_size= img_size,
    batch_size = batch,
    label_mode ='binary'
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../test01/test_sample/",
    #seed=123,
    image_size= img_size,
    batch_size = batch,
    #label_mode = None
)

class_names = test_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)


preprocess_input = tf.keras.applications.efficientnet.preprocess_input

data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomFlip('vertical'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2)
])

base_model = tf.keras.applications.EfficientNetB0(input_shape = (224, 224, 3),
                                                    include_top = False,
                                                    weights = 'imagenet')

base_model.trainable = False
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(1)

inputs = tf.keras.Input(shape=(224,224, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = prediction_layer(x)
outputs = tf.nn.sigmoid(x)
model = tf.keras.Model(inputs, outputs)

base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
              metrics=['accuracy','Recall', 'Precision', 'FalsePositives', 'TruePositives', 'FalseNegatives'])
# Out:
# Found 2800 files belonging to 2 classes.
# Using 2100 files for training.
# Found 1156 files belonging to 2 classes.
# Using 289 files for validation.
# Found 800 files belonging to 2 classes.

# %%
epochs=100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  #steps_per_epoch = 100,
  #callbacks = [DisplayCallback()]
)
# Out:
# Epoch 1/100
# 132/132 [==============================] - 41s 239ms/step - loss: 0.6083 - accuracy: 0.6881 - recall: 0.7363 - precision: 0.6690 - false_positives: 380.0000 - true_positives: 768.0000 - false_negatives: 275.0000 - val_loss: 0.4498 - val_accuracy: 0.8893 - val_recall: 0.8472 - val_precision: 0.7439 - val_false_positives: 21.0000 - val_true_positives: 61.0000 - val_false_negatives: 11.0000
# Epoch 2/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.4477 - accuracy: 0.8333 - recall: 0.9041 - precision: 0.7904 - false_positives: 250.0000 - true_positives: 943.0000 - false_negatives: 100.0000 - val_loss: 0.3237 - val_accuracy: 0.9170 - val_recall: 0.9583 - val_precision: 0.7667 - val_false_positives: 21.0000 - val_true_positives: 69.0000 - val_false_negatives: 3.0000
# Epoch 3/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.3768 - accuracy: 0.8633 - recall: 0.9367 - precision: 0.8155 - false_positives: 221.0000 - true_positives: 977.0000 - false_negatives: 66.0000 - val_loss: 0.2676 - val_accuracy: 0.9204 - val_recall: 0.9583 - val_precision: 0.7753 - val_false_positives: 20.0000 - val_true_positives: 69.0000 - val_false_negatives: 3.0000
# Epoch 4/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.3375 - accuracy: 0.8805 - recall: 0.9645 - precision: 0.8246 - false_positives: 214.0000 - true_positives: 1006.0000 - false_negatives: 37.0000 - val_loss: 0.2356 - val_accuracy: 0.9204 - val_recall: 0.9583 - val_precision: 0.7753 - val_false_positives: 20.0000 - val_true_positives: 69.0000 - val_false_negatives: 3.0000
# Epoch 5/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.3087 - accuracy: 0.8910 - recall: 0.9664 - precision: 0.8386 - false_positives: 194.0000 - true_positives: 1008.0000 - false_negatives: 35.0000 - val_loss: 0.2170 - val_accuracy: 0.9135 - val_recall: 0.9583 - val_precision: 0.7582 - val_false_positives: 22.0000 - val_true_positives: 69.0000 - val_false_negatives: 3.0000
# Epoch 6/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.2909 - accuracy: 0.8900 - recall: 0.9722 - precision: 0.8339 - false_positives: 202.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.2038 - val_accuracy: 0.9170 - val_recall: 0.9583 - val_precision: 0.7667 - val_false_positives: 21.0000 - val_true_positives: 69.0000 - val_false_negatives: 3.0000
# Epoch 7/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.2729 - accuracy: 0.9019 - recall: 0.9779 - precision: 0.8479 - false_positives: 183.0000 - true_positives: 1020.0000 - false_negatives: 23.0000 - val_loss: 0.1944 - val_accuracy: 0.9204 - val_recall: 0.9722 - val_precision: 0.7692 - val_false_positives: 21.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 8/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.2631 - accuracy: 0.9000 - recall: 0.9751 - precision: 0.8468 - false_positives: 184.0000 - true_positives: 1017.0000 - false_negatives: 26.0000 - val_loss: 0.1862 - val_accuracy: 0.9239 - val_recall: 0.9722 - val_precision: 0.7778 - val_false_positives: 20.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 9/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.2570 - accuracy: 0.9029 - recall: 0.9684 - precision: 0.8552 - false_positives: 171.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1790 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 10/100
# 132/132 [==============================] - 28s 211ms/step - loss: 0.2480 - accuracy: 0.9062 - recall: 0.9674 - precision: 0.8609 - false_positives: 163.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1740 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 11/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.2362 - accuracy: 0.9105 - recall: 0.9674 - precision: 0.8676 - false_positives: 154.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1708 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 12/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.2389 - accuracy: 0.9052 - recall: 0.9616 - precision: 0.8632 - false_positives: 159.0000 - true_positives: 1003.0000 - false_negatives: 40.0000 - val_loss: 0.1665 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 13/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.2280 - accuracy: 0.9133 - recall: 0.9712 - precision: 0.8695 - false_positives: 152.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1639 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 14/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.2225 - accuracy: 0.9162 - recall: 0.9693 - precision: 0.8753 - false_positives: 144.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1603 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 15/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.2222 - accuracy: 0.9152 - recall: 0.9674 - precision: 0.8751 - false_positives: 144.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1581 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 16/100
# 132/132 [==============================] - 28s 216ms/step - loss: 0.2141 - accuracy: 0.9186 - recall: 0.9703 - precision: 0.8785 - false_positives: 140.0000 - true_positives: 1012.0000 - false_negatives: 31.0000 - val_loss: 0.1572 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 17/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.2105 - accuracy: 0.9152 - recall: 0.9732 - precision: 0.8712 - false_positives: 150.0000 - true_positives: 1015.0000 - false_negatives: 28.0000 - val_loss: 0.1555 - val_accuracy: 0.9239 - val_recall: 0.9722 - val_precision: 0.7778 - val_false_positives: 20.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 18/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.2081 - accuracy: 0.9186 - recall: 0.9722 - precision: 0.8772 - false_positives: 142.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1526 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 19/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.2071 - accuracy: 0.9200 - recall: 0.9693 - precision: 0.8814 - false_positives: 136.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1499 - val_accuracy: 0.9273 - val_recall: 0.9722 - val_precision: 0.7865 - val_false_positives: 19.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 20/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.2018 - accuracy: 0.9233 - recall: 0.9712 - precision: 0.8855 - false_positives: 131.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1480 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 21/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.2004 - accuracy: 0.9195 - recall: 0.9703 - precision: 0.8800 - false_positives: 138.0000 - true_positives: 1012.0000 - false_negatives: 31.0000 - val_loss: 0.1465 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 22/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1915 - accuracy: 0.9276 - recall: 0.9712 - precision: 0.8925 - false_positives: 122.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1440 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 23/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1933 - accuracy: 0.9286 - recall: 0.9741 - precision: 0.8920 - false_positives: 123.0000 - true_positives: 1016.0000 - false_negatives: 27.0000 - val_loss: 0.1436 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 24/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1902 - accuracy: 0.9276 - recall: 0.9741 - precision: 0.8904 - false_positives: 125.0000 - true_positives: 1016.0000 - false_negatives: 27.0000 - val_loss: 0.1427 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 25/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1868 - accuracy: 0.9324 - recall: 0.9760 - precision: 0.8969 - false_positives: 117.0000 - true_positives: 1018.0000 - false_negatives: 25.0000 - val_loss: 0.1421 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 26/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1882 - accuracy: 0.9286 - recall: 0.9712 - precision: 0.8941 - false_positives: 120.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1404 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 27/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1802 - accuracy: 0.9262 - recall: 0.9645 - precision: 0.8950 - false_positives: 118.0000 - true_positives: 1006.0000 - false_negatives: 37.0000 - val_loss: 0.1399 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 28/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1798 - accuracy: 0.9300 - recall: 0.9684 - precision: 0.8986 - false_positives: 114.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1387 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 29/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1803 - accuracy: 0.9314 - recall: 0.9712 - precision: 0.8988 - false_positives: 114.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1374 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 30/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1820 - accuracy: 0.9357 - recall: 0.9722 - precision: 0.9054 - false_positives: 106.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1376 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 31/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1711 - accuracy: 0.9343 - recall: 0.9722 - precision: 0.9029 - false_positives: 109.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1354 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 32/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1647 - accuracy: 0.9438 - recall: 0.9770 - precision: 0.9155 - false_positives: 94.0000 - true_positives: 1019.0000 - false_negatives: 24.0000 - val_loss: 0.1352 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 33/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1762 - accuracy: 0.9333 - recall: 0.9664 - precision: 0.9057 - false_positives: 105.0000 - true_positives: 1008.0000 - false_negatives: 35.0000 - val_loss: 0.1342 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 34/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1812 - accuracy: 0.9262 - recall: 0.9684 - precision: 0.8922 - false_positives: 122.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1332 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 35/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1731 - accuracy: 0.9348 - recall: 0.9664 - precision: 0.9081 - false_positives: 102.0000 - true_positives: 1008.0000 - false_negatives: 35.0000 - val_loss: 0.1319 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 36/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1770 - accuracy: 0.9310 - recall: 0.9636 - precision: 0.9038 - false_positives: 107.0000 - true_positives: 1005.0000 - false_negatives: 38.0000 - val_loss: 0.1321 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 37/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1736 - accuracy: 0.9324 - recall: 0.9645 - precision: 0.9055 - false_positives: 105.0000 - true_positives: 1006.0000 - false_negatives: 37.0000 - val_loss: 0.1323 - val_accuracy: 0.9343 - val_recall: 0.9722 - val_precision: 0.8046 - val_false_positives: 17.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 38/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1649 - accuracy: 0.9333 - recall: 0.9674 - precision: 0.9049 - false_positives: 106.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1319 - val_accuracy: 0.9308 - val_recall: 0.9722 - val_precision: 0.7955 - val_false_positives: 18.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 39/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1655 - accuracy: 0.9352 - recall: 0.9703 - precision: 0.9060 - false_positives: 105.0000 - true_positives: 1012.0000 - false_negatives: 31.0000 - val_loss: 0.1305 - val_accuracy: 0.9377 - val_recall: 0.9722 - val_precision: 0.8140 - val_false_positives: 16.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 40/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1720 - accuracy: 0.9376 - recall: 0.9722 - precision: 0.9086 - false_positives: 102.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1291 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 41/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1668 - accuracy: 0.9333 - recall: 0.9722 - precision: 0.9013 - false_positives: 111.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1270 - val_accuracy: 0.9377 - val_recall: 0.9722 - val_precision: 0.8140 - val_false_positives: 16.0000 - val_true_positives: 70.0000 - val_false_negatives: 2.0000
# Epoch 42/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1642 - accuracy: 0.9357 - recall: 0.9664 - precision: 0.9097 - false_positives: 100.0000 - true_positives: 1008.0000 - false_negatives: 35.0000 - val_loss: 0.1254 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 43/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1568 - accuracy: 0.9443 - recall: 0.9779 - precision: 0.9156 - false_positives: 94.0000 - true_positives: 1020.0000 - false_negatives: 23.0000 - val_loss: 0.1236 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 44/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1616 - accuracy: 0.9419 - recall: 0.9674 - precision: 0.9198 - false_positives: 88.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1239 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 45/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1602 - accuracy: 0.9390 - recall: 0.9732 - precision: 0.9103 - false_positives: 100.0000 - true_positives: 1015.0000 - false_negatives: 28.0000 - val_loss: 0.1238 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 46/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1629 - accuracy: 0.9395 - recall: 0.9674 - precision: 0.9156 - false_positives: 93.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1235 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 47/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1596 - accuracy: 0.9414 - recall: 0.9741 - precision: 0.9137 - false_positives: 96.0000 - true_positives: 1016.0000 - false_negatives: 27.0000 - val_loss: 0.1230 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 48/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1535 - accuracy: 0.9443 - recall: 0.9712 - precision: 0.9209 - false_positives: 87.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1232 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 49/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1552 - accuracy: 0.9381 - recall: 0.9674 - precision: 0.9131 - false_positives: 96.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1220 - val_accuracy: 0.9412 - val_recall: 0.9861 - val_precision: 0.8161 - val_false_positives: 16.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 50/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1553 - accuracy: 0.9395 - recall: 0.9722 - precision: 0.9119 - false_positives: 98.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1211 - val_accuracy: 0.9446 - val_recall: 0.9861 - val_precision: 0.8256 - val_false_positives: 15.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 51/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.1523 - accuracy: 0.9414 - recall: 0.9712 - precision: 0.9159 - false_positives: 93.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1201 - val_accuracy: 0.9446 - val_recall: 0.9861 - val_precision: 0.8256 - val_false_positives: 15.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 52/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1567 - accuracy: 0.9405 - recall: 0.9684 - precision: 0.9165 - false_positives: 92.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1183 - val_accuracy: 0.9446 - val_recall: 0.9861 - val_precision: 0.8256 - val_false_positives: 15.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 53/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.1556 - accuracy: 0.9390 - recall: 0.9693 - precision: 0.9133 - false_positives: 96.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1184 - val_accuracy: 0.9446 - val_recall: 0.9861 - val_precision: 0.8256 - val_false_positives: 15.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 54/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1454 - accuracy: 0.9471 - recall: 0.9732 - precision: 0.9244 - false_positives: 83.0000 - true_positives: 1015.0000 - false_negatives: 28.0000 - val_loss: 0.1176 - val_accuracy: 0.9446 - val_recall: 0.9861 - val_precision: 0.8256 - val_false_positives: 15.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 55/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.1539 - accuracy: 0.9405 - recall: 0.9693 - precision: 0.9158 - false_positives: 93.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1158 - val_accuracy: 0.9516 - val_recall: 0.9861 - val_precision: 0.8452 - val_false_positives: 13.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 56/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1525 - accuracy: 0.9443 - recall: 0.9722 - precision: 0.9201 - false_positives: 88.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1154 - val_accuracy: 0.9516 - val_recall: 0.9861 - val_precision: 0.8452 - val_false_positives: 13.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 57/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1533 - accuracy: 0.9357 - recall: 0.9626 - precision: 0.9127 - false_positives: 96.0000 - true_positives: 1004.0000 - false_negatives: 39.0000 - val_loss: 0.1155 - val_accuracy: 0.9516 - val_recall: 1.0000 - val_precision: 0.8372 - val_false_positives: 14.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 58/100
# 132/132 [==============================] - 28s 216ms/step - loss: 0.1498 - accuracy: 0.9443 - recall: 0.9684 - precision: 0.9232 - false_positives: 84.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1158 - val_accuracy: 0.9516 - val_recall: 1.0000 - val_precision: 0.8372 - val_false_positives: 14.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 59/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1558 - accuracy: 0.9414 - recall: 0.9693 - precision: 0.9174 - false_positives: 91.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1137 - val_accuracy: 0.9550 - val_recall: 1.0000 - val_precision: 0.8471 - val_false_positives: 13.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 60/100
# 132/132 [==============================] - 28s 216ms/step - loss: 0.1449 - accuracy: 0.9414 - recall: 0.9703 - precision: 0.9167 - false_positives: 92.0000 - true_positives: 1012.0000 - false_negatives: 31.0000 - val_loss: 0.1134 - val_accuracy: 0.9550 - val_recall: 1.0000 - val_precision: 0.8471 - val_false_positives: 13.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 61/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1456 - accuracy: 0.9495 - recall: 0.9741 - precision: 0.9279 - false_positives: 79.0000 - true_positives: 1016.0000 - false_negatives: 27.0000 - val_loss: 0.1119 - val_accuracy: 0.9550 - val_recall: 0.9861 - val_precision: 0.8554 - val_false_positives: 12.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 62/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1404 - accuracy: 0.9543 - recall: 0.9751 - precision: 0.9356 - false_positives: 70.0000 - true_positives: 1017.0000 - false_negatives: 26.0000 - val_loss: 0.1114 - val_accuracy: 0.9550 - val_recall: 0.9861 - val_precision: 0.8554 - val_false_positives: 12.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 63/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1430 - accuracy: 0.9438 - recall: 0.9674 - precision: 0.9231 - false_positives: 84.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1115 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 64/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1415 - accuracy: 0.9419 - recall: 0.9684 - precision: 0.9190 - false_positives: 89.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1102 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 65/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1434 - accuracy: 0.9467 - recall: 0.9693 - precision: 0.9267 - false_positives: 80.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1096 - val_accuracy: 0.9585 - val_recall: 0.9861 - val_precision: 0.8659 - val_false_positives: 11.0000 - val_true_positives: 71.0000 - val_false_negatives: 1.0000
# Epoch 66/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1418 - accuracy: 0.9495 - recall: 0.9760 - precision: 0.9263 - false_positives: 81.0000 - true_positives: 1018.0000 - false_negatives: 25.0000 - val_loss: 0.1098 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 67/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1440 - accuracy: 0.9405 - recall: 0.9674 - precision: 0.9173 - false_positives: 91.0000 - true_positives: 1009.0000 - false_negatives: 34.0000 - val_loss: 0.1106 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 68/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1447 - accuracy: 0.9448 - recall: 0.9722 - precision: 0.9210 - false_positives: 87.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1111 - val_accuracy: 0.9550 - val_recall: 1.0000 - val_precision: 0.8471 - val_false_positives: 13.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 69/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1312 - accuracy: 0.9533 - recall: 0.9789 - precision: 0.9307 - false_positives: 76.0000 - true_positives: 1021.0000 - false_negatives: 22.0000 - val_loss: 0.1102 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 70/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1402 - accuracy: 0.9457 - recall: 0.9684 - precision: 0.9258 - false_positives: 81.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1092 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 71/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1415 - accuracy: 0.9486 - recall: 0.9770 - precision: 0.9238 - false_positives: 84.0000 - true_positives: 1019.0000 - false_negatives: 24.0000 - val_loss: 0.1091 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 72/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1431 - accuracy: 0.9443 - recall: 0.9732 - precision: 0.9194 - false_positives: 89.0000 - true_positives: 1015.0000 - false_negatives: 28.0000 - val_loss: 0.1083 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 73/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1368 - accuracy: 0.9476 - recall: 0.9722 - precision: 0.9260 - false_positives: 81.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1079 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 74/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1372 - accuracy: 0.9448 - recall: 0.9664 - precision: 0.9256 - false_positives: 81.0000 - true_positives: 1008.0000 - false_negatives: 35.0000 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 75/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1391 - accuracy: 0.9510 - recall: 0.9770 - precision: 0.9281 - false_positives: 79.0000 - true_positives: 1019.0000 - false_negatives: 24.0000 - val_loss: 0.1088 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 76/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1316 - accuracy: 0.9524 - recall: 0.9722 - precision: 0.9346 - false_positives: 71.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1092 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 77/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1340 - accuracy: 0.9452 - recall: 0.9684 - precision: 0.9249 - false_positives: 82.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1088 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 78/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.1351 - accuracy: 0.9467 - recall: 0.9722 - precision: 0.9243 - false_positives: 83.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1076 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 79/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1389 - accuracy: 0.9510 - recall: 0.9703 - precision: 0.9336 - false_positives: 72.0000 - true_positives: 1012.0000 - false_negatives: 31.0000 - val_loss: 0.1078 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 80/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1340 - accuracy: 0.9486 - recall: 0.9770 - precision: 0.9238 - false_positives: 84.0000 - true_positives: 1019.0000 - false_negatives: 24.0000 - val_loss: 0.1072 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 81/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1340 - accuracy: 0.9538 - recall: 0.9808 - precision: 0.9300 - false_positives: 77.0000 - true_positives: 1023.0000 - false_negatives: 20.0000 - val_loss: 0.1072 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 82/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1282 - accuracy: 0.9514 - recall: 0.9732 - precision: 0.9320 - false_positives: 74.0000 - true_positives: 1015.0000 - false_negatives: 28.0000 - val_loss: 0.1096 - val_accuracy: 0.9550 - val_recall: 1.0000 - val_precision: 0.8471 - val_false_positives: 13.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 83/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1349 - accuracy: 0.9505 - recall: 0.9741 - precision: 0.9296 - false_positives: 77.0000 - true_positives: 1016.0000 - false_negatives: 27.0000 - val_loss: 0.1086 - val_accuracy: 0.9585 - val_recall: 1.0000 - val_precision: 0.8571 - val_false_positives: 12.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 84/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.1314 - accuracy: 0.9524 - recall: 0.9770 - precision: 0.9306 - false_positives: 76.0000 - true_positives: 1019.0000 - false_negatives: 24.0000 - val_loss: 0.1073 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 85/100
# 132/132 [==============================] - 28s 215ms/step - loss: 0.1299 - accuracy: 0.9529 - recall: 0.9722 - precision: 0.9354 - false_positives: 70.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1060 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 86/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1347 - accuracy: 0.9471 - recall: 0.9722 - precision: 0.9252 - false_positives: 82.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1049 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 87/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1363 - accuracy: 0.9510 - recall: 0.9684 - precision: 0.9352 - false_positives: 70.0000 - true_positives: 1010.0000 - false_negatives: 33.0000 - val_loss: 0.1046 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 88/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1325 - accuracy: 0.9529 - recall: 0.9741 - precision: 0.9338 - false_positives: 72.0000 - true_positives: 1016.0000 - false_negatives: 27.0000 - val_loss: 0.1044 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 89/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1302 - accuracy: 0.9538 - recall: 0.9799 - precision: 0.9308 - false_positives: 76.0000 - true_positives: 1022.0000 - false_negatives: 21.0000 - val_loss: 0.1040 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 90/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1324 - accuracy: 0.9495 - recall: 0.9645 - precision: 0.9358 - false_positives: 69.0000 - true_positives: 1006.0000 - false_negatives: 37.0000 - val_loss: 0.1040 - val_accuracy: 0.9654 - val_recall: 1.0000 - val_precision: 0.8780 - val_false_positives: 10.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 91/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1284 - accuracy: 0.9519 - recall: 0.9732 - precision: 0.9329 - false_positives: 73.0000 - true_positives: 1015.0000 - false_negatives: 28.0000 - val_loss: 0.1037 - val_accuracy: 0.9619 - val_recall: 1.0000 - val_precision: 0.8675 - val_false_positives: 11.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 92/100
# 132/132 [==============================] - 28s 214ms/step - loss: 0.1379 - accuracy: 0.9495 - recall: 0.9722 - precision: 0.9294 - false_positives: 77.0000 - true_positives: 1014.0000 - false_negatives: 29.0000 - val_loss: 0.1033 - val_accuracy: 0.9654 - val_recall: 1.0000 - val_precision: 0.8780 - val_false_positives: 10.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 93/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1343 - accuracy: 0.9467 - recall: 0.9712 - precision: 0.9251 - false_positives: 82.0000 - true_positives: 1013.0000 - false_negatives: 30.0000 - val_loss: 0.1017 - val_accuracy: 0.9654 - val_recall: 1.0000 - val_precision: 0.8780 - val_false_positives: 10.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 94/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1261 - accuracy: 0.9562 - recall: 0.9751 - precision: 0.9391 - false_positives: 66.0000 - true_positives: 1017.0000 - false_negatives: 26.0000 - val_loss: 0.1011 - val_accuracy: 0.9723 - val_recall: 1.0000 - val_precision: 0.9000 - val_false_positives: 8.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 95/100
# 132/132 [==============================] - 28s 211ms/step - loss: 0.1329 - accuracy: 0.9505 - recall: 0.9693 - precision: 0.9335 - false_positives: 72.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1019 - val_accuracy: 0.9689 - val_recall: 1.0000 - val_precision: 0.8889 - val_false_positives: 9.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 96/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1312 - accuracy: 0.9462 - recall: 0.9664 - precision: 0.9282 - false_positives: 78.0000 - true_positives: 1008.0000 - false_negatives: 35.0000 - val_loss: 0.1014 - val_accuracy: 0.9723 - val_recall: 1.0000 - val_precision: 0.9000 - val_false_positives: 8.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 97/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1218 - accuracy: 0.9581 - recall: 0.9770 - precision: 0.9409 - false_positives: 64.0000 - true_positives: 1019.0000 - false_negatives: 24.0000 - val_loss: 0.1002 - val_accuracy: 0.9723 - val_recall: 1.0000 - val_precision: 0.9000 - val_false_positives: 8.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 98/100
# 132/132 [==============================] - 28s 212ms/step - loss: 0.1279 - accuracy: 0.9543 - recall: 0.9779 - precision: 0.9332 - false_positives: 73.0000 - true_positives: 1020.0000 - false_negatives: 23.0000 - val_loss: 0.1005 - val_accuracy: 0.9723 - val_recall: 1.0000 - val_precision: 0.9000 - val_false_positives: 8.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 99/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1206 - accuracy: 0.9548 - recall: 0.9789 - precision: 0.9333 - false_positives: 73.0000 - true_positives: 1021.0000 - false_negatives: 22.0000 - val_loss: 0.0999 - val_accuracy: 0.9723 - val_recall: 1.0000 - val_precision: 0.9000 - val_false_positives: 8.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00
# Epoch 100/100
# 132/132 [==============================] - 28s 213ms/step - loss: 0.1279 - accuracy: 0.9533 - recall: 0.9693 - precision: 0.9387 - false_positives: 66.0000 - true_positives: 1011.0000 - false_negatives: 32.0000 - val_loss: 0.1008 - val_accuracy: 0.9723 - val_recall: 1.0000 - val_precision: 0.9000 - val_false_positives: 8.0000 - val_true_positives: 72.0000 - val_false_negatives: 0.0000e+00

# %%
len(val_ds)
# Out:
# 19

# %%
loss, accuracy, recall, precision, fp, tp, fn = model.evaluate(val_ds)
print('Test accuracy :', accuracy)
print('Test recall :', recall)
print('Test precision :', precision)
print('False Positive :', fp)
print('True Positive :', tp)
print('False Negative :', fn)
tn = len(val_ds)-fp-tp-fn
print('True Negative :', tn)
print('F1 :', (2*(precision*recall))/(precision + recall))
# Out:
# 19/19 [==============================] - 3s 168ms/step - loss: 0.1008 - accuracy: 0.9723 - recall: 1.0000 - precision: 0.9000 - false_positives: 8.0000 - true_positives: 72.0000 - false_negatives: 0.0000e+00
# Test accuracy : 0.9723183512687683
# Test recall : 1.0
# Test precision : 0.8999999761581421
# False Positive : 8.0
# True Positive : 72.0
# False Negative : 0.0
# True Negative : -61.0
# F1 : 0.9473684078438459

# %%
model.save('../train_w_model02A/wHC_1_1.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
acc = history.history['recall']
val_acc = history.history['val_recall']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Recall')
plt.plot(epochs_range, val_acc, label='Validation Recall')
plt.legend(loc='lower right')
plt.title('Training and Validation Recall')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
acc = history.history['precision']
val_acc = history.history['val_precision']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training precision')
plt.plot(epochs_range, val_acc, label='Validation precision')
plt.legend(loc='lower right')
plt.title('Training and Validation precision')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
len(test_ds)
# Out:
# 50

# %%
loss, accuracy, recall, precision, fp, tp, fn = model.evaluate(test_ds)
print('Test accuracy :', accuracy)
print('Test recall :', recall)
print('Test precision :', precision)
print('False Positive :', fp)
print('True Positive :', tp)
print('False Negative :', fn)
tn = len(test_ds)-fp-tp-fn
print('True Negative :', tn)
print('F1 :', (2*(precision*recall))/(precision + recall))
# Out:
# 50/50 [==============================] - 12s 183ms/step - loss: 0.1073 - accuracy: 0.9675 - recall: 0.9750 - precision: 0.9606 - false_positives: 16.0000 - true_positives: 390.0000 - false_negatives: 10.0000
# Test accuracy : 0.9674999713897705
# Test recall : 0.9750000238418579
# Test precision : 0.9605911374092102
# False Positive : 16.0
# True Positive : 390.0
# False Negative : 10.0
# True Negative : -366.0
# F1 : 0.9677419494630279

# %%
loss, accuracy, recall, precision, fp, tp, fn = model.evaluate(train_ds)
print('Test accuracy :', accuracy)
print('Test recall :', recall)
print('Test precision :', precision)
print('False Positive :', fp)
print('True Positive :', tp)
print('False Negative :', fn)
tn = len(train_ds)-fp-tp-fn
print('True Negative :', tn)
print('F1 :', (2*(precision*recall))/(precision + recall))
# Out:
# 132/132 [==============================] - 23s 172ms/step - loss: 0.1056 - accuracy: 0.9657 - recall: 0.9732 - precision: 0.9585 - false_positives: 44.0000 - true_positives: 1015.0000 - false_negatives: 28.0000
# Test accuracy : 0.9657142758369446
# Test recall : 0.9731543660163879
# Test precision : 0.9584513902664185
# False Positive : 44.0
# True Positive : 1015.0
# False Negative : 28.0
# True Negative : -955.0
# F1 : 0.9657469201657135

# %%
# 128 x 128 Model - val_generator
'''
10/10 [==============================] - 1s 115ms/step - loss: 0.1810 - accuracy: 0.9170 - recall: 0.8889 - precision: 0.8000 - false_positives: 16.0000 - true_positives: 64.0000 - false_negatives: 8.0000
Test accuracy : 0.9169549942016602
Test recall : 0.8888888955116272
Test precision : 0.800000011920929
False Positive : 16.0
True Positive : 64.0
False Negative : 8.0
True Negative : -78.0
F1 : 0.8421052727342643
'''

# %%
# 128 x 128 Model - train_generator
'''
66/66 [==============================] - 8s 124ms/step - loss: 0.1856 - accuracy: 0.9352 - recall: 0.9473 - precision: 0.9242 - false_positives: 81.0000 - true_positives: 988.0000 - false_negatives: 55.0000
Test accuracy : 0.9352381229400635
Test recall : 0.947267472743988
Test precision : 0.9242282509803772
False Positive : 81.0
True Positive : 988.0
False Negative : 55.0
True Negative : -1058.0
F1 : 0.9356060486235137
'''

# %%
# 128 x 128 Model - test_generator
'''
25/25 [==============================] - 4s 139ms/step - loss: 0.1913 - accuracy: 0.9312 - recall: 0.9250 - precision: 0.9367 - false_positives: 25.0000 - true_positives: 370.0000 - false_negatives: 30.0000
Test accuracy : 0.9312499761581421
Test recall : 0.925000011920929
Test precision : 0.9367088675498962
False Positive : 25.0
True Positive : 370.0
False Negative : 30.0
True Negative : -400.0
F1 : 0.9308176194511963
'''

# %%
# 224 x 224 Model - val_generator
'''
19/19 [==============================] - 3s 168ms/step - loss: 0.1008 - accuracy: 0.9723 - recall: 1.0000 - precision: 0.9000 - false_positives: 8.0000 - true_positives: 72.0000 - false_negatives: 0.0000e+00
Test accuracy : 0.9723183512687683
Test recall : 1.0
Test precision : 0.8999999761581421
False Positive : 8.0
True Positive : 72.0
False Negative : 0.0
True Negative : -61.0
F1 : 0.9473684078438459
'''

# %%
# 224 x 224 Model - train_generator
'''
132/132 [==============================] - 23s 172ms/step - loss: 0.1056 - accuracy: 0.9657 - recall: 0.9732 - precision: 0.9585 - false_positives: 44.0000 - true_positives: 1015.0000 - false_negatives: 28.0000
Test accuracy : 0.9657142758369446
Test recall : 0.9731543660163879
Test precision : 0.9584513902664185
False Positive : 44.0
True Positive : 1015.0
False Negative : 28.0
True Negative : -955.0
F1 : 0.9657469201657135
'''

# %%
# 224 x 224 Model - test_generator
'''
50/50 [==============================] - 12s 183ms/step - loss: 0.1073 - accuracy: 0.9675 - recall: 0.9750 - precision: 0.9606 - false_positives: 16.0000 - true_positives: 390.0000 - false_negatives: 10.0000
Test accuracy : 0.9674999713897705
Test recall : 0.9750000238418579
Test precision : 0.9605911374092102
False Positive : 16.0
True Positive : 390.0
False Negative : 10.0
True Negative : -366.0
F1 : 0.9677419494630279
'''
